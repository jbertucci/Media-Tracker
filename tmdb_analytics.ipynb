# %%
import importlib
import tmdb_helpers
importlib.reload(tmdb_helpers)
from tmdb_helpers import *

# %%
setup_analytics_db()
# Out:
# Analytics DB ready.

# %%
##add_movie('The Big Lebowski')
##remove_movie('The Big Lebowski')

# %%
import_from_csv('Media - Movies.csv')

# %%
##remove_movie('Princess Mono')
add_movie('Better Man', '4/16')
# Out:
# Search results:
#   [1] Better Man (2024)
#   [2] Better Man (2022)
#   [3] Better Man (2018)
#   [4] The Better Man (1916)
#   [5] Better Man (2016)
#
# Adding: Better Man (2024)
# Stored: Better Man (2024)
# Wikidata enrichment: 0 of 449 people had ethnicity or sexuality data.
# 799766

# %%
view_movies()
# Out:
# #     Title                                         Year   Added (UTC)        Last Watched (UTC) Watches
# ----------------------------------------------------------------------------------------------------
# 1     Joker                                         2019   2021-06-18         2021-06-18         1
# 2     Inside Llewyn Davis                           2013   2021-06-30         2021-06-30         1
# 3     Twilight                                      2008   2021-08-21         2021-08-21         1
# 4     The Twilight Saga: New Moon                   2009   2021-08-21         2021-08-21         1
# 5     The Twilight Saga: Eclipse                    2010   2021-09-09         2021-09-09         1
# 6     The Twilight Saga: Breaking Dawn - Part 1     2011   2021-09-18         2021-09-18         1
# 7     Shang-Chi and the Legend of the Ten Rings     2021   2021-09-25         2021-09-25         1
# ...
